# %%
# Import the dependencies. Most of this from the WeatheryPy exercise (detailes changed).
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

import requests

from config import weather_api_key

import time
import timeit
from datetime import datetime

from citipy import citipy

# %%
#3. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#4. Get the nearest city usingthe citipy module
cities = [] 

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
#5. Perform an API call with Open Weather Map
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#6 Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
       
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | north bend
# Processing Record 7 of Set 1 | touros
# Processing Record 8 of Set 1 | iskateley
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | ongandjera
# Processing Record 11 of Set 1 | lavrentiya
# Processing Record 12 of Set 1 | karratha
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | inhambane
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | umba
# Processing Record 26 of Set 1 | umm kaddadah
# Processing Record 27 of Set 1 | statesboro
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | porto novo
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | christchurch
# Processing Record 33 of Set 1 | korla
# Processing Record 34 of Set 1 | mohgaon
# Processing Record 35 of Set 1 | hami
# Processing Record 36 of Set 1 | caninde de sao francisco
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | bosobolo
# Processing Record 39 of Set 1 | lebork
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | deputatskiy
# Processing Record 44 of Set 1 | guarapari
# Processing Record 45 of Set 1 | fort nelson
# Processing Record 46 of Set 1 | mati
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 1 | champerico
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | tonshayevo
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | isangel
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | sanchor
# Processing Record 9 of Set 2 | luangwa
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | alekseyevsk
# Processing Record 15 of Set 2 | vanino
# Processing Record 16 of Set 2 | lasa
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | erzin
# Processing Record 22 of Set 2 | mogocha
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | fernandina beach
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | mujiayingzi
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | yar-sale
# Processing Record 31 of Set 2 | paita
# Processing Record 32 of Set 2 | college
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | ahuimanu
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | hanna
# Processing Record 37 of Set 2 | presidencia roque saenz pena
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | leh
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | novikovo
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | katsina
# Processing Record 49 of Set 2 | marfino
# Processing Record 50 of Set 2 | manggar
# Processing Record 1 of Set 3 | bustonkala
# City not found. Skipping...
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | mount isa
# Processing Record 4 of Set 3 | boma
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | mitsamiouli
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | la solana
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | aklavik
# Processing Record 12 of Set 3 | mayna
# Processing Record 13 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 14 of Set 3 | anchorage
# Processing Record 15 of Set 3 | bereznik
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | razdolinsk
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 3 | slave lake
# Processing Record 22 of Set 3 | whitehorse
# Processing Record 23 of Set 3 | loandjili
# Processing Record 24 of Set 3 | hurricane
# Processing Record 25 of Set 3 | mehamn
# Processing Record 26 of Set 3 | alofi
# Processing Record 27 of Set 3 | baiyin
# Processing Record 28 of Set 3 | ixtapa
# Processing Record 29 of Set 3 | byron bay
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | kaliua
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 35 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | jaswantnagar
# Processing Record 40 of Set 3 | darhan
# Processing Record 41 of Set 3 | lazaro cardenas
# Processing Record 42 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | samarai
# Processing Record 45 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | kuching
# Processing Record 50 of Set 3 | lompoc
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | la ronge
# Processing Record 3 of Set 4 | ipubi
# Processing Record 4 of Set 4 | karasjok
# Processing Record 5 of Set 4 | polson
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | freeport
# Processing Record 9 of Set 4 | port macquarie
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | ajdabiya
# Processing Record 13 of Set 4 | aksaray
# Processing Record 14 of Set 4 | poretskoye
# Processing Record 15 of Set 4 | chavakkad
# Processing Record 16 of Set 4 | hualmay
# Processing Record 17 of Set 4 | puyo
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | kulhudhuffushi
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 4 | olafsvik
# Processing Record 23 of Set 4 | roma
# Processing Record 24 of Set 4 | kamaishi
# Processing Record 25 of Set 4 | labuhan
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | half moon bay
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | puerto madryn
# Processing Record 30 of Set 4 | qeshm
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | rudnogorsk
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | bitung
# Processing Record 38 of Set 4 | myaundzha
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | homer
# Processing Record 41 of Set 4 | tessalit
# Processing Record 42 of Set 4 | guarda
# Processing Record 43 of Set 4 | sorland
# Processing Record 44 of Set 4 | neiafu
# Processing Record 45 of Set 4 | ningxiang
# Processing Record 46 of Set 4 | tazovskiy
# Processing Record 47 of Set 4 | carlet
# Processing Record 48 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 4 | dingle
# Processing Record 50 of Set 4 | pathein
# Processing Record 1 of Set 5 | yasnyy
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | luang prabang
# Processing Record 4 of Set 5 | nesbyen
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | lugovoy
# Processing Record 7 of Set 5 | lanxi
# Processing Record 8 of Set 5 | puri
# Processing Record 9 of Set 5 | tautira
# Processing Record 10 of Set 5 | guapore
# Processing Record 11 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | ambon
# Processing Record 15 of Set 5 | coruripe
# Processing Record 16 of Set 5 | moussoro
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | pringsewu
# Processing Record 19 of Set 5 | oussouye
# Processing Record 20 of Set 5 | ust-omchug
# Processing Record 21 of Set 5 | okmulgee
# Processing Record 22 of Set 5 | ibicarai
# Processing Record 23 of Set 5 | beloha
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 5 | biltine
# Processing Record 27 of Set 5 | mayor pablo lagerenza
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 5 | yumen
# Processing Record 31 of Set 5 | trincomalee
# Processing Record 32 of Set 5 | kwinana
# Processing Record 33 of Set 5 | santa maria
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | souillac
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | lensk
# Processing Record 38 of Set 5 | nakamura
# Processing Record 39 of Set 5 | kalmunai
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | sokolo
# Processing Record 42 of Set 5 | gizo
# Processing Record 43 of Set 5 | ouanaminthe
# Processing Record 44 of Set 5 | liverpool
# Processing Record 45 of Set 5 | riverton
# Processing Record 46 of Set 5 | lata
# Processing Record 47 of Set 5 | tura
# Processing Record 48 of Set 5 | aitape
# Processing Record 49 of Set 5 | payo
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | sistranda
# Processing Record 2 of Set 6 | buchanan
# Processing Record 3 of Set 6 | devonport
# Processing Record 4 of Set 6 | micheweni
# Processing Record 5 of Set 6 | saint-augustin
# Processing Record 6 of Set 6 | chikitigarh
# Processing Record 7 of Set 6 | ashington
# Processing Record 8 of Set 6 | kijang
# Processing Record 9 of Set 6 | numan
# Processing Record 10 of Set 6 | qaanaaq
# Processing Record 11 of Set 6 | usinsk
# Processing Record 12 of Set 6 | tyup
# Processing Record 13 of Set 6 | nikolayevka
# Processing Record 14 of Set 6 | acapulco
# Processing Record 15 of Set 6 | kolokani
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | umiray
# Processing Record 19 of Set 6 | yellowknife
# Processing Record 20 of Set 6 | isiolo
# Processing Record 21 of Set 6 | tairua
# Processing Record 22 of Set 6 | turayf
# Processing Record 23 of Set 6 | ust-tsilma
# Processing Record 24 of Set 6 | kankakee
# Processing Record 25 of Set 6 | labe
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | axim
# Processing Record 28 of Set 6 | labrea
# Processing Record 29 of Set 6 | jumla
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | omaruru
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | bahia blanca
# Processing Record 35 of Set 6 | cabedelo
# Processing Record 36 of Set 6 | lahij
# Processing Record 37 of Set 6 | baruun-urt
# Processing Record 38 of Set 6 | kipini
# Processing Record 39 of Set 6 | kotar
# Processing Record 40 of Set 6 | fatehpur sikri
# Processing Record 41 of Set 6 | along
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | lukang
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | carnarvon
# Processing Record 47 of Set 6 | oyama
# Processing Record 48 of Set 6 | sobolevo
# Processing Record 49 of Set 6 | vanavara
# Processing Record 50 of Set 6 | evensk
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | muroto
# Processing Record 3 of Set 7 | atuona
# Processing Record 4 of Set 7 | havoysund
# Processing Record 5 of Set 7 | qianan
# Processing Record 6 of Set 7 | harnosand
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | zeya
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | wagar
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | gusau
# Processing Record 14 of Set 7 | maldonado
# Processing Record 15 of Set 7 | sakakah
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | wanaka
# Processing Record 18 of Set 7 | manali
# Processing Record 19 of Set 7 | taoudenni
# Processing Record 20 of Set 7 | san andres
# Processing Record 21 of Set 7 | los llanos de aridane
# Processing Record 22 of Set 7 | tromso
# Processing Record 23 of Set 7 | dunedin
# Processing Record 24 of Set 7 | aswan
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | palmer
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | darlawn
# Processing Record 29 of Set 7 | zavetnoye
# Processing Record 30 of Set 7 | port-cartier
# Processing Record 31 of Set 7 | sawakin
# Processing Record 32 of Set 7 | mackay
# Processing Record 33 of Set 7 | alibag
# Processing Record 34 of Set 7 | dubna
# Processing Record 35 of Set 7 | muravlenko
# Processing Record 36 of Set 7 | moron
# Processing Record 37 of Set 7 | raymond terrace
# Processing Record 38 of Set 7 | toktogul
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | general roca
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | aksarka
# Processing Record 43 of Set 7 | kozmodemyansk
# Processing Record 44 of Set 7 | nishihara
# Processing Record 45 of Set 7 | iqaluit
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | svetlaya
# Processing Record 48 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | zaraza
# Processing Record 1 of Set 8 | yanam
# Processing Record 2 of Set 8 | kawalu
# Processing Record 3 of Set 8 | saint-pierre
# Processing Record 4 of Set 8 | mormugao
# Processing Record 5 of Set 8 | katsuura
# Processing Record 6 of Set 8 | el vigia
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | mankapur
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | ciudad bolivar
# Processing Record 11 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 8 | mubi
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | faratsiho
# Processing Record 15 of Set 8 | kenai
# Processing Record 16 of Set 8 | beringovskiy
# Processing Record 17 of Set 8 | rusera
# Processing Record 18 of Set 8 | cedar rapids
# Processing Record 19 of Set 8 | high point
# Processing Record 20 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 21 of Set 8 | cayenne
# Processing Record 22 of Set 8 | bandar-e lengeh
# Processing Record 23 of Set 8 | nagpandayan
# Processing Record 24 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 8 | nuevo progreso
# Processing Record 27 of Set 8 | nizwa
# Processing Record 28 of Set 8 | cairns
# Processing Record 29 of Set 8 | katy
# Processing Record 30 of Set 8 | mikhaylovka
# Processing Record 31 of Set 8 | plaster rock
# Processing Record 32 of Set 8 | ayan
# Processing Record 33 of Set 8 | ukiah
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | puerto madero
# Processing Record 36 of Set 8 | coos bay
# Processing Record 37 of Set 8 | leamington
# Processing Record 38 of Set 8 | ouagadougou
# Processing Record 39 of Set 8 | thinadhoo
# Processing Record 40 of Set 8 | gunnedah
# Processing Record 41 of Set 8 | lorengau
# Processing Record 42 of Set 8 | okato
# Processing Record 43 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 8 | genhe
# Processing Record 45 of Set 8 | pandan
# Processing Record 46 of Set 8 | puerto baquerizo moreno
# Processing Record 47 of Set 8 | birakan
# Processing Record 48 of Set 8 | nueva guinea
# Processing Record 49 of Set 8 | upington
# Processing Record 50 of Set 8 | torit
# Processing Record 1 of Set 9 | goundam
# Processing Record 2 of Set 9 | nantucket
# Processing Record 3 of Set 9 | madaoua
# Processing Record 4 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 5 of Set 9 | bacolod
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 9 | chimbote
# Processing Record 9 of Set 9 | hyeres
# Processing Record 10 of Set 9 | segovia
# Processing Record 11 of Set 9 | paramonga
# Processing Record 12 of Set 9 | pietarsaari
# Processing Record 13 of Set 9 | alexandria
# Processing Record 14 of Set 9 | aksehir
# Processing Record 15 of Set 9 | guadalupe y calvo
# Processing Record 16 of Set 9 | kutum
# Processing Record 17 of Set 9 | akyab
# Processing Record 18 of Set 9 | santa barbara
# Processing Record 19 of Set 9 | kaeo
# Processing Record 20 of Set 9 | durusu
# Processing Record 21 of Set 9 | finsterwalde
# Processing Record 22 of Set 9 | miranda
# Processing Record 23 of Set 9 | talnakh
# Processing Record 24 of Set 9 | nizhniy mamon
# Processing Record 25 of Set 9 | narsaq
# Processing Record 26 of Set 9 | george town
# Processing Record 27 of Set 9 | puerto leguizamo
# Processing Record 28 of Set 9 | lewistown
# Processing Record 29 of Set 9 | edd
# Processing Record 30 of Set 9 | belyy yar
# Processing Record 31 of Set 9 | oyonnax
# Processing Record 32 of Set 9 | almeirim
# Processing Record 33 of Set 9 | north battleford
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | bat khela
# Processing Record 36 of Set 9 | cascavel
# Processing Record 37 of Set 9 | valparaiso
# Processing Record 38 of Set 9 | lumberton
# Processing Record 39 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 9 | poum
# Processing Record 42 of Set 9 | mahanoro
# Processing Record 43 of Set 9 | rocha
# Processing Record 44 of Set 9 | alice springs
# Processing Record 45 of Set 9 | lokot
# Processing Record 46 of Set 9 | vostok
# Processing Record 47 of Set 9 | bud
# Processing Record 48 of Set 9 | maksatikha
# Processing Record 49 of Set 9 | marawi
# Processing Record 50 of Set 9 | sillod
# Processing Record 1 of Set 10 | chiang rai
# Processing Record 2 of Set 10 | sokoni
# Processing Record 3 of Set 10 | pinega
# Processing Record 4 of Set 10 | san-pedro
# Processing Record 5 of Set 10 | nacala
# Processing Record 6 of Set 10 | killybegs
# Processing Record 7 of Set 10 | praia da vitoria
# Processing Record 8 of Set 10 | russkaya polyana
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | sola
# Processing Record 11 of Set 10 | medea
# Processing Record 12 of Set 10 | villa carlos paz
# Processing Record 13 of Set 10 | pangai
# Processing Record 14 of Set 10 | ketchikan
# Processing Record 15 of Set 10 | san pedro
# Processing Record 16 of Set 10 | mabaruma
# Processing Record 17 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 10 | margate
# Processing Record 19 of Set 10 | yerbogachen
# Processing Record 20 of Set 10 | xining
# Processing Record 21 of Set 10 | lac-megantic
# Processing Record 22 of Set 10 | angoche
# Processing Record 23 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 10 | yendi
# Processing Record 25 of Set 10 | aygut
# Processing Record 26 of Set 10 | namibe
# Processing Record 27 of Set 10 | vetluzhskiy
# Processing Record 28 of Set 10 | port blair
# Processing Record 29 of Set 10 | talcahuano
# Processing Record 30 of Set 10 | alvorada
# Processing Record 31 of Set 10 | remscheid
# Processing Record 32 of Set 10 | yeppoon
# Processing Record 33 of Set 10 | verkhoyansk
# Processing Record 34 of Set 10 | lakatoro
# Processing Record 35 of Set 10 | trairi
# Processing Record 36 of Set 10 | suntar
# Processing Record 37 of Set 10 | macamic
# Processing Record 38 of Set 10 | maceio
# Processing Record 39 of Set 10 | kavieng
# Processing Record 40 of Set 10 | cabra
# Processing Record 41 of Set 10 | hlobyne
# Processing Record 42 of Set 10 | winnemucca
# Processing Record 43 of Set 10 | vestmannaeyjar
# Processing Record 44 of Set 10 | harper
# Processing Record 45 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 10 | calama
# Processing Record 47 of Set 10 | spring hill
# Processing Record 48 of Set 10 | caluquembe
# Processing Record 49 of Set 10 | kyren
# Processing Record 50 of Set 10 | osinovo
# Processing Record 1 of Set 11 | novoaleksandrovsk
# Processing Record 2 of Set 11 | dzhebariki-khaya
# Processing Record 3 of Set 11 | kirakira
# Processing Record 4 of Set 11 | sinnamary
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | nigde
# Processing Record 7 of Set 11 | bonavista
# Processing Record 8 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 11 | hibbing
# Processing Record 10 of Set 11 | waipawa
# Processing Record 11 of Set 11 | santa fe
# Processing Record 12 of Set 11 | fort dodge
# Processing Record 13 of Set 11 | charleville-mezieres
# Processing Record 14 of Set 11 | zyryanka
# Processing Record 15 of Set 11 | trelew
# Processing Record 16 of Set 11 | lerwick
# Processing Record 17 of Set 11 | carora
# Processing Record 18 of Set 11 | shu
# Processing Record 19 of Set 11 | dalbandin
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | general delgado
# Processing Record 22 of Set 11 | hoshangabad
# Processing Record 23 of Set 11 | wembley
# Processing Record 24 of Set 11 | smithers
# Processing Record 25 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 11 | salinopolis
# Processing Record 27 of Set 11 | karachi
# Processing Record 28 of Set 11 | itarema
# Processing Record 29 of Set 11 | beidao
# Processing Record 30 of Set 11 | norman wells
# Processing Record 31 of Set 11 | bahia honda
# Processing Record 32 of Set 11 | argir
# Processing Record 33 of Set 11 | hirara
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | zainsk
# Processing Record 36 of Set 11 | garh maharaja
# Processing Record 37 of Set 11 | saint-joseph
# Processing Record 38 of Set 11 | keffi
# Processing Record 39 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 11 | chalmette
# Processing Record 41 of Set 11 | evanston
# Processing Record 42 of Set 11 | dalby
# Processing Record 43 of Set 11 | kasongo
# Processing Record 44 of Set 11 | pangnirtung
# Processing Record 45 of Set 11 | simao
# Processing Record 46 of Set 11 | nago
# Processing Record 47 of Set 11 | tecoanapa
# Processing Record 48 of Set 11 | chochola
# Processing Record 49 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 50 of Set 11 | yola
# Processing Record 1 of Set 12 | lluta
# Processing Record 2 of Set 12 | tillabery
# City not found. Skipping...
# Processing Record 3 of Set 12 | salta
# Processing Record 4 of Set 12 | maryville
# Processing Record 5 of Set 12 | aykhal
# Processing Record 6 of Set 12 | brae
# Processing Record 7 of Set 12 | les cayes
# Processing Record 8 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 12 | pawa
# Processing Record 10 of Set 12 | trinidad
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 12 | mezen
# Processing Record 14 of Set 12 | salamiyah
# Processing Record 15 of Set 12 | puerto colombia
# Processing Record 16 of Set 12 | gold coast
# Processing Record 17 of Set 12 | ponta delgada
# Processing Record 18 of Set 12 | kyra
# Processing Record 19 of Set 12 | richards bay
# Processing Record 20 of Set 12 | sao felix do xingu
# Processing Record 21 of Set 12 | dwarka
# Processing Record 22 of Set 12 | banda aceh
# Processing Record 23 of Set 12 | staryy nadym
# Processing Record 24 of Set 12 | luau
# Processing Record 25 of Set 12 | port hardy
# Processing Record 26 of Set 12 | racine
# Processing Record 27 of Set 12 | vila
# Processing Record 28 of Set 12 | nadym
# Processing Record 29 of Set 12 | saint anthony
# Processing Record 30 of Set 12 | george
# Processing Record 31 of Set 12 | octeville
# Processing Record 32 of Set 12 | rio gallegos
# Processing Record 33 of Set 12 | ayr
# Processing Record 34 of Set 12 | esqueda
# Processing Record 35 of Set 12 | borovsk
# Processing Record 36 of Set 12 | hofn
# Processing Record 37 of Set 12 | cap malheureux
# Processing Record 38 of Set 12 | kapoeta
# Processing Record 39 of Set 12 | karatau
# Processing Record 40 of Set 12 | boddam
# Processing Record 41 of Set 12 | lethem
# Processing Record 42 of Set 12 | van
# Processing Record 43 of Set 12 | syracuse
# Processing Record 44 of Set 12 | meihekou
# Processing Record 45 of Set 12 | rathenow
# Processing Record 46 of Set 12 | kembe
# Processing Record 47 of Set 12 | pirmasens
# Processing Record 48 of Set 12 | zakharo
# City not found. Skipping...
# Processing Record 49 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 12 | sovetsk
# Processing Record 1 of Set 13 | bayan
# Processing Record 2 of Set 13 | sirvintos
# Processing Record 3 of Set 13 | teguldet
# Processing Record 4 of Set 13 | mhango
# Processing Record 5 of Set 13 | ust-kut
# Processing Record 6 of Set 13 | cardoso
# Processing Record 7 of Set 13 | sargatskoye
# Processing Record 8 of Set 13 | chichimila
# Processing Record 9 of Set 13 | salalah
# Processing Record 10 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | adrar
# Processing Record 12 of Set 13 | broken hill
# Processing Record 13 of Set 13 | saint-ambroise
# Processing Record 14 of Set 13 | coahuayana
# Processing Record 15 of Set 13 | sawtell
# Processing Record 16 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 13 | peachland
# Processing Record 18 of Set 13 | japura
# Processing Record 19 of Set 13 | duiwelskloof
# Processing Record 20 of Set 13 | hanyang
# Processing Record 21 of Set 13 | norsup
# Processing Record 22 of Set 13 | acolla
# Processing Record 23 of Set 13 | port augusta
# Processing Record 24 of Set 13 | daru
# Processing Record 25 of Set 13 | sturgeon falls
# Processing Record 26 of Set 13 | amahai
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | baracoa
# Processing Record 29 of Set 13 | alta floresta
# Processing Record 30 of Set 13 | chokwe
# Processing Record 31 of Set 13 | dandong
# Processing Record 32 of Set 13 | krasnovishersk
# Processing Record 33 of Set 13 | meulaboh
# Processing Record 34 of Set 13 | chara
# Processing Record 35 of Set 13 | progreso
# Processing Record 36 of Set 13 | tiznit
# Processing Record 37 of Set 13 | mombetsu
# Processing Record 38 of Set 13 | zhezkazgan
# Processing Record 39 of Set 13 | lac du bonnet
# Processing Record 40 of Set 13 | ohara
# Processing Record 41 of Set 13 | awbari
# Processing Record 42 of Set 13 | osterhofen
# Processing Record 43 of Set 13 | labuan
# Processing Record 44 of Set 13 | visby
# Processing Record 45 of Set 13 | lodja
# Processing Record 46 of Set 13 | prince rupert
# Processing Record 47 of Set 13 | matagami
# Processing Record 48 of Set 13 | banff
# Processing Record 49 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 50 of Set 13 | petatlan
# Processing Record 1 of Set 14 | hobyo
# Processing Record 2 of Set 14 | harlingen
# Processing Record 3 of Set 14 | katherine
# Processing Record 4 of Set 14 | la romana
# Processing Record 5 of Set 14 | jieshi
# Processing Record 6 of Set 14 | chimbarongo
# Processing Record 7 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | mesimerion
# Processing Record 9 of Set 14 | gari
# Processing Record 10 of Set 14 | urucara
# Processing Record 11 of Set 14 | taltal
# Processing Record 12 of Set 14 | takoradi
# Processing Record 13 of Set 14 | barao de melgaco
# Processing Record 14 of Set 14 | banyo
# Processing Record 15 of Set 14 | faya
# Processing Record 16 of Set 14 | gushikawa
# Processing Record 17 of Set 14 | melita
# Processing Record 18 of Set 14 | rio grande
# Processing Record 19 of Set 14 | dondo
# Processing Record 20 of Set 14 | tocopilla
# Processing Record 21 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 14 | charyshskoye
# Processing Record 23 of Set 14 | naze
# Processing Record 24 of Set 14 | sofiyivka
# Processing Record 25 of Set 14 | hambantota
# Processing Record 26 of Set 14 | pasighat
# Processing Record 27 of Set 14 | farap
# Processing Record 28 of Set 14 | matsanga
# City not found. Skipping...
# Processing Record 29 of Set 14 | fairmount
# Processing Record 30 of Set 14 | gaggenau
# Processing Record 31 of Set 14 | kidal
# Processing Record 32 of Set 14 | wanlaweyn
# Processing Record 33 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 14 | shingu
# Processing Record 35 of Set 14 | mahibadhoo
# Processing Record 36 of Set 14 | coihaique
# Processing Record 37 of Set 14 | teluknaga
# Processing Record 38 of Set 14 | walvis bay
# Processing Record 39 of Set 14 | sitka
# Processing Record 40 of Set 14 | atbasar
# Processing Record 41 of Set 14 | gualaceo
# Processing Record 42 of Set 14 | srandakan
# Processing Record 43 of Set 14 | peruibe
# Processing Record 44 of Set 14 | ometepec
# Processing Record 45 of Set 14 | yulara
# Processing Record 46 of Set 14 | vanderhoof
# Processing Record 47 of Set 14 | roura
# Processing Record 48 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 49 of Set 14 | nenjiang
# Processing Record 50 of Set 14 | ropczyce
# Processing Record 1 of Set 15 | morro bay
# Processing Record 2 of Set 15 | ratnagiri
# Processing Record 3 of Set 15 | ulaangom
# Processing Record 4 of Set 15 | pasaquina
# Processing Record 5 of Set 15 | anori
# Processing Record 6 of Set 15 | pili
# Processing Record 7 of Set 15 | santa cruz de la palma
# Processing Record 8 of Set 15 | nome
# Processing Record 9 of Set 15 | tadine
# Processing Record 10 of Set 15 | laurel
# Processing Record 11 of Set 15 | olga
# Processing Record 12 of Set 15 | natchitoches
# Processing Record 13 of Set 15 | alyangula
# Processing Record 14 of Set 15 | anloga
# Processing Record 15 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 15 | mezhdurechenskiy
# Processing Record 17 of Set 15 | zhigansk
# Processing Record 18 of Set 15 | kargil
# Processing Record 19 of Set 15 | dinguiraye
# Processing Record 20 of Set 15 | honningsvag
# Processing Record 21 of Set 15 | talagang
# Processing Record 22 of Set 15 | haines junction
# Processing Record 23 of Set 15 | erenhot
# Processing Record 24 of Set 15 | opuwo
# Processing Record 25 of Set 15 | tatawin
# Processing Record 26 of Set 15 | crotone
# Processing Record 27 of Set 15 | calabozo
# Processing Record 28 of Set 15 | raudeberg
# Processing Record 29 of Set 15 | graaff-reinet
# Processing Record 30 of Set 15 | saquarema
# Processing Record 31 of Set 15 | vakhrushev
# Processing Record 32 of Set 15 | atka
# City not found. Skipping...
# Processing Record 33 of Set 15 | niquero
# Processing Record 34 of Set 15 | vila franca do campo
# Processing Record 35 of Set 15 | baykit
# Processing Record 36 of Set 15 | bamiantong
# Processing Record 37 of Set 15 | aqtobe
# Processing Record 38 of Set 15 | lagunas
# Processing Record 39 of Set 15 | namie
# Processing Record 40 of Set 15 | griffith
# Processing Record 41 of Set 15 | tynda
# Processing Record 42 of Set 15 | tselinnoye
# Processing Record 43 of Set 15 | tartus
# Processing Record 44 of Set 15 | mareeba
# Processing Record 45 of Set 15 | banswada
# Processing Record 46 of Set 15 | desbiens
# Processing Record 47 of Set 15 | sisimiut
# Processing Record 48 of Set 15 | garowe
# Processing Record 49 of Set 15 | krasnoselkup
# Processing Record 50 of Set 15 | linxia
# Processing Record 1 of Set 16 | dubbo
# Processing Record 2 of Set 16 | ballina
# Processing Record 3 of Set 16 | padang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 695

# %%
#7 Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khatanga      RU  71.9667  102.5000    -26.05       100         100
# 1  Saint-Philippe      RE -21.3585   55.7679     80.19        89         100
# 2          Castro      BR -24.7911  -50.0119     69.19        67          28
# 3    Punta Arenas      CL -53.1500  -70.9167     57.31        54          75
# 4          Barrow      US  71.2906 -156.7887    -25.58        68           0
# 5      North Bend      US  43.4065 -124.2243     51.08        96         100
# 6          Touros      BR  -5.1989  -35.4608     83.57        69          71
# 7       Iskateley      RU  67.6803   53.1512     25.23        93         100
# 8      Ongandjera      NA -17.8833   15.0667     80.13        51          95
# 9      Lavrentiya      RU  65.5833 -171.0000     -2.79        92         100
#
#    Wind Speed Current Description
# 0        4.47     overcast clouds
# 1       11.86          light rain
# 2       10.56    scattered clouds
# 3       31.07       broken clouds
# 4        4.61           clear sky
# 5        9.22                mist
# 6       11.52       moderate rain
# 7       17.87          light snow
# 8       11.03          light rain
# 9        2.15     overcast clouds

# %%
#8 Export the DataFrame as a CSV file, 
# and save it as WeatherPy_Database.csv in the Weather_Database folder.

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
